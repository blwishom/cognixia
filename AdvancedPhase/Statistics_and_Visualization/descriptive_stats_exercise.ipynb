# %%
'''
Exercise prompt (until lunch): Find a Seaborn dataset and explore it in detail! 
Take a look at measures of central tendency, distribution, and shape for particular variables! 
Examine individual variables, compare groups within a single variable, or take a look at bivariate distributions! 
Keep in mind the kind of variable (qualitative/quantitave, discrete/continuous) you're looking at as that will effect your plot!

'''
# Out:
# "\nExercise prompt (until lunch): Find a Seaborn dataset and explore it in detail! \nTake a look at measures of central tendency, distribution, and shape for particular variables! \nExamine individual variables, compare groups within a single variable, or take a look at bivariate distributions! \nKeep in mind the kind of variable (qualitative/quantitave, discrete/continuous) you're looking at as that will effect your plot!\n\n"

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
exercise = sns.load_dataset('exercise')
exercise
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
print(exercise['diet'].unique(), '<---DIETS')
print(' ')
print(exercise['kind'].unique(), '<---ACTIVITIES')
print(' ')
print(exercise['time'].unique(), '<---TIMES')
# Out:
# ['low fat', 'no fat']
# Categories (2, object): ['no fat', 'low fat'] <---DIETS
#
# ['rest', 'walking', 'running']
# Categories (3, object): ['rest', 'walking', 'running'] <---ACTIVITIES
#
# ['1 min', '15 min', '30 min']
# Categories (3, object): ['1 min', '15 min', '30 min'] <---TIMES

# %%
# print(exercise['diet'].unique())
# print(exercise['pulse'])

diet_pulse = pd.DataFrame(exercise, columns=['diet', 'pulse', 'kind'])
print(diet_pulse[:30])
# Out:
#        diet  pulse  kind
# 0   low fat     85  rest
# 1   low fat     85  rest
# 2   low fat     88  rest
# 3   low fat     90  rest
# 4   low fat     92  rest
# 5   low fat     93  rest
# 6   low fat     97  rest
# 7   low fat     97  rest
# 8   low fat     94  rest
# 9   low fat     80  rest
# 10  low fat     82  rest
# 11  low fat     83  rest
# 12  low fat     91  rest
# 13  low fat     92  rest
# 14  low fat     91  rest
# 15   no fat     83  rest
# 16   no fat     83  rest
# 17   no fat     84  rest
# 18   no fat     87  rest
# 19   no fat     88  rest
# 20   no fat     90  rest
# 21   no fat     92  rest
# 22   no fat     94  rest
# 23   no fat     95  rest
# 24   no fat     97  rest
# 25   no fat     99  rest
# 26   no fat     96  rest
# 27   no fat    100  rest
# 28   no fat     97  rest
# 29   no fat    100  rest

# %%
sns.displot(exercise, x='pulse', kind='kde', color='black')
# sns.set(rc={'axes.facecolor':'black'})
sns.set(style='dark')

# plt.yticks([])
# plt.ylabel('')

mean = exercise.pulse.mean()
median = exercise.pulse.median()
mode = exercise.pulse.mode()[0]

plt.axvline(x=mean, color='blue')
plt.axvline(x=median, color='red')
plt.axvline(x=mode, color='orange')

plt.legend(['Pulse', 'Mean', 'Median', 'Mode'])

# %%
sns.displot(exercise, x='pulse', hue='time', kind='kde', multiple='stack')
# sns.set(rc={'axes.facecolor':'black'})
sns.set(style='dark')

# %%
sns.displot(exercise, x='pulse', hue='diet', kind='kde', multiple='fill')
# sns.set(rc={'axes.facecolor':'black'})
sns.set(style='dark')

# %%
sns.kdeplot(exercise, x='pulse', hue='time', multiple='stack')
# sns.set(rc={'axes.facecolor':'black'})
sns.set(style='dark')

# %%
sns.histplot(exercise, x='pulse', hue='diet', multiple='stack')
# sns.set(rc={'axes.facecolor':'black'})
sns.set(style='dark')

# %%
sns.displot(exercise, x='pulse', kind='hist')
# sns.set(rc={'axes.facecolor':'black'})
sns.set(style='dark')

# %%
exercise['pulse'].skew()
# Out:
# 1.5504450351421257

# %%
sns.displot(exercise, x="pulse", hue="diet", kind='hist')
plt.show()

# %%
sns.pairplot(exercise, hue="diet", kind='hist')
plt.show()

# %%
sns.pairplot(exercise, hue="time", kind='hist')
plt.show()

# %%
sns.boxplot(exercise, x='diet', y='pulse')
# sns.set(rc={'axes.facecolor':'black'})
sns.set(style='dark')

# %%
sns.boxplot(exercise, x='pulse', y='diet')
# sns.set(rc={'axes.facecolor':'black'})
sns.set(style='dark')

# %%
sns.boxplot(exercise, x='pulse', y='diet', hue='time')
# sns.set(rc={'axes.facecolor':'black'})
sns.set(style='dark')

# %%
sns.boxplot(exercise, x='time', y='pulse', hue='diet', orient='v')
# sns.set(rc={'axes.facecolor':'black'})
sns.set(style='dark')

# %%
sns.violinplot(data=exercise, x='pulse', y='diet')
# sns.set(rc={'axes.facecolor':'black'})
sns.set(style='dark')

# %%
sns.violinplot(data=exercise, x='pulse', y='kind', hue='time')
# sns.set(rc={'axes.facecolor':'black'})
sns.set(style='dark')

# %%
sns.pointplot(data=exercise, x='pulse', y='diet', hue='time')
# sns.set(rc={'axes.facecolor':'black'})
sns.set(style='dark')

# %%
sns.pointplot(data=exercise, x='pulse', y='kind')
# sns.set(rc={'axes.facecolor':'black'})
sns.set(style='dark')
