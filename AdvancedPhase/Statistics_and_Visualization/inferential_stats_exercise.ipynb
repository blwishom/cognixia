# %%
'''
Exercise until afternoon break: Perform inferential statistics on a couple different variables of your choice in the dataset you were working on previously. 
Be sure to confirm the statistical significance of your conclusions. 
Come up with a few insights and be prepared to present your findings in visual form to your new PEP teammates after break!

'''
# Out:
# '\nExercise until afternoon break: Perform inferential statistics on a couple different variables of your choice in the dataset you were working on previously. \nBe sure to confirm the statistical significance of your conclusions. \nCome up with a few insights and be prepared to present your findings in visual form to your new PEP teammates after break!\n\n'

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
healthexp = sns.load_dataset('healthexp')
healthexp
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
sns.regplot(data=healthexp, x='Spending_USD', y='Life_Expectancy')
plt.show()

# %%
sns.regplot(data=healthexp, x='Life_Expectancy', y='Spending_USD')
plt.show()
