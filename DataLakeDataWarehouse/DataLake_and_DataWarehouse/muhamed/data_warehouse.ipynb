# %%
import pandas as pd, sqlite3 as s3

# %%
conn = s3.connect("archive (2)/database.sqlite")

# %% [markdown]
# This section will focus on the Player Table from archive 2. This table lists information on baseball players' name, DOB, country, and playstyle

# %%
c = conn.execute("SELECT name FROM sqlite_master WHERE type='table'").fetchall()
for l in c: print(l)
# Out:
# ('Player',)
# ('Extra_Runs',)
# ('Batsman_Scored',)
# ('Batting_Style',)
# ('Bowling_Style',)
# ('Country',)
# ('Season',)
# ('City',)
# ('Outcome',)
# ('Win_By',)
# ('Wicket_Taken',)
# ('Venue',)
# ('Extra_Type',)
# ('Out_Type',)
# ('Toss_Decision',)
# ('Umpire',)
# ('Team',)
# ('Ball_by_Ball',)
# ('sysdiagrams',)
# ('sqlite_sequence',)
# ('Match',)
# ('Rolee',)
# ('Player_Match',)

# %%
player_df = pd.read_sql_query("select * from player", conn)
player_df["DOB"] = pd.to_datetime(player_df["DOB"])
player_df.set_index("Player_Id", inplace=True)

player_df.head()
# Out:
#                Player_Name        DOB  Batting_hand  Bowling_skill
# Player_Id
# 1               SC Ganguly 1972-07-08             1            1.0  \
# 2              BB McCullum 1981-09-27             2            1.0
# 3               RT Ponting 1974-12-19             2            1.0
# 4                DJ Hussey 1977-07-15             2            2.0
# 5          Mohammad Hafeez 1980-10-17             2            2.0
#
#            Country_Name
# Player_Id
# 1                     1
# 2                     4
# 3                     5
# 4                     5
# 5                     6

# %%
player_df.isna().sum()
# Out:
# Player_Name       0
# DOB               0
# Batting_hand      0
# Bowling_skill    43
# Country_Name      0
# dtype: int64

# %% [markdown]
# Now to clean the data.
# First we notice that there are 43 players whose bowling skill entries are missing, so we fill them with 0s for now

# %%
player_df.fillna({"Bowling_skill":0}, inplace=True)
player_df.isnull().sum()
# Out:
# Player_Name      0
# DOB              0
# Batting_hand     0
# Bowling_skill    0
# Country_Name     0
# dtype: int64

# %%
player_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# After filling in the missing bowling skills we check for duplicates, which there are none of.

# %%
country_df = pd.read_sql_query("select * from country", conn).set_index("Country_Id")
print(country_df)
print()
batting_df = pd.read_sql_query("SELECT * FROM Batting_Style", conn).set_index("Batting_Id")
print(batting_df)
print()
bowling_df = pd.read_sql_query("SELECT * FROM Bowling_Style", conn).set_index("Bowling_Id")
print(bowling_df)
# Out:
#             Country_Name
# Country_Id
# 1                  India
# 2           South Africa
# 3                  U.A.E
# 4            New Zealand
# 5              Australia
# 6               Pakistan
# 7              Sri Lanka
# 8            West Indies
# 9              Zimbabwea
# 10               England
# 11            Bangladesh
# 12           Netherlands
#
#               Batting_hand
# Batting_Id
# 1            Left-hand bat
# 2           Right-hand bat
#
#                      Bowling_skill
# Bowling_Id
# 1                 Right-arm medium
# 2               Right-arm offbreak
# 3            Right-arm fast-medium
# 4                  Legbreak googly
# 5            Right-arm medium-fast
# 6             Left-arm fast-medium
# 7           Slow left-arm orthodox
# 8           Slow left-arm chinaman
# 9             Left-arm medium-fast
# 10                        Legbreak
# 11                  Right-arm fast
# 12                Right-arm bowler
# 13                 Left-arm medium
# 14                   Left-arm fast

# %%
bowling_df.head(14)
# Out:
#                      Bowling_skill
# Bowling_Id
# 1                 Right-arm medium
# 2               Right-arm offbreak
# 3            Right-arm fast-medium
# 4                  Legbreak googly
# 5            Right-arm medium-fast
# 6             Left-arm fast-medium
# 7           Slow left-arm orthodox
# 8           Slow left-arm chinaman
# 9             Left-arm medium-fast
# 10                        Legbreak
# 11                  Right-arm fast
# 12                Right-arm bowler
# 13                 Left-arm medium
# 14                   Left-arm fast

# %% [markdown]
# Now we have to de-normalize this table. This will involve taking the referenced tables and combining them with the player table. To that end, we examine those tables. These are the country names, batting hands, and bowling skill types referred to by player. Next we convert the Bowling_skill series in player_df to int for consistency:

# %%
player_df["Bowling_skill"] = player_df["Bowling_skill"].astype(int)
player_df.head(20)
# Out:
#                Player_Name        DOB  Batting_hand  Bowling_skill
# Player_Id
# 1               SC Ganguly 1972-07-08             1              1  \
# 2              BB McCullum 1981-09-27             2              1
# 3               RT Ponting 1974-12-19             2              1
# 4                DJ Hussey 1977-07-15             2              2
# 5          Mohammad Hafeez 1980-10-17             2              2
# 6                 R Dravid 1973-01-11             2              2
# 7                 W Jaffer 1978-02-16             2              2
# 8                  V Kohli 1988-11-05             2              1
# 9                JH Kallis 1975-10-16             2              3
# 10                CL White 1983-08-18             2              4
# 11              MV Boucher 1976-12-03             2              1
# 12                 B Akhil 1977-10-07             2              5
# 13               AA Noffke 1977-04-30             2              3
# 14                 P Kumar 1986-10-02             2              1
# 15                  Z Khan 1978-10-07             2              6
# 16                SB Joshi 1970-06-06             1              7
# 17                PA Patel 1985-03-09             1              0
# 18               ML Hayden 1971-10-29             1              1
# 19              MEK Hussey 1975-05-27             1              1
# 20                MS Dhoni 1981-07-07             2              1
#
#            Country_Name
# Player_Id
# 1                     1
# 2                     4
# 3                     5
# 4                     5
# 5                     6
# 6                     1
# 7                     1
# 8                     1
# 9                     2
# 10                    5
# 11                    2
# 12                    1
# 13                    5
# 14                    1
# 15                    1
# 16                    1
# 17                    1
# 18                    5
# 19                    5
# 20                    1

# %% [markdown]
# Now to combine the tables by replacing their reference ids with their corresponding values:

# %%
player_df["Country_Name"] = player_df["Country_Name"].replace(1, "India")\
    .replace(2, "South Africa").replace(3, "U.A.E").replace(4, "New Zealand")\
    .replace(5,"Australia").replace(6, "Pakistan").replace(7, "Sri Lanka")\
    .replace(8, "West Indies").replace(9, "Zimbabwea").replace(10, "England")\
    .replace(11, "Bangladesh").replace(12, "Netherlands")

# %%
player_df["Batting_hand"] = player_df["Batting_hand"].replace(1, "Left-hand bat")\
    .replace(2, "Right-hand bat")

# %%
player_df["Bowling_skill"] = player_df["Bowling_skill"].replace(1, "Right-arm medium")\
    .replace(2, "Right-arm offbreak").replace(3, "Right-arm fast-medium").replace(4, "Legbreak googly")\
    .replace(5,"Right-arm medium-fast").replace(6, "Left-arm fast-medium").replace(7, "Slow left-arm orthodox")\
    .replace(8, "Slow left-arm chinaman").replace(9, "Left-arm medium-fast").replace(10, "Legbreak")\
    .replace(11, "Right-arm fast").replace(12, "Right-arm bowler").replace(13, "Left-arm medium")\
    .replace(14, "Left-arm fast").replace(0, "Unspecified")

# %%
player_df.head(25)
# Out:
#                Player_Name        DOB    Batting_hand           Bowling_skill
# Player_Id
# 1               SC Ganguly 1972-07-08   Left-hand bat        Right-arm medium  \
# 2              BB McCullum 1981-09-27  Right-hand bat        Right-arm medium
# 3               RT Ponting 1974-12-19  Right-hand bat        Right-arm medium
# 4                DJ Hussey 1977-07-15  Right-hand bat      Right-arm offbreak
# 5          Mohammad Hafeez 1980-10-17  Right-hand bat      Right-arm offbreak
# 6                 R Dravid 1973-01-11  Right-hand bat      Right-arm offbreak
# 7                 W Jaffer 1978-02-16  Right-hand bat      Right-arm offbreak
# 8                  V Kohli 1988-11-05  Right-hand bat        Right-arm medium
# 9                JH Kallis 1975-10-16  Right-hand bat   Right-arm fast-medium
# 10                CL White 1983-08-18  Right-hand bat         Legbreak googly
# 11              MV Boucher 1976-12-03  Right-hand bat        Right-arm medium
# 12                 B Akhil 1977-10-07  Right-hand bat   Right-arm medium-fast
# 13               AA Noffke 1977-04-30  Right-hand bat   Right-arm fast-medium
# 14                 P Kumar 1986-10-02  Right-hand bat        Right-arm medium
# 15                  Z Khan 1978-10-07  Right-hand bat    Left-arm fast-medium
# 16                SB Joshi 1970-06-06   Left-hand bat  Slow left-arm orthodox
# 17                PA Patel 1985-03-09   Left-hand bat             Unspecified
# 18               ML Hayden 1971-10-29   Left-hand bat        Right-arm medium
# 19              MEK Hussey 1975-05-27   Left-hand bat        Right-arm medium
# 20                MS Dhoni 1981-07-07  Right-hand bat        Right-arm medium
# 21                SK Raina 1986-11-27   Left-hand bat      Right-arm offbreak
# 22                JDP Oram 1978-07-28   Left-hand bat   Right-arm fast-medium
# 23             S Badrinath 1980-08-30  Right-hand bat      Right-arm offbreak
# 24                  K Goel 1986-12-24   Left-hand bat      Right-arm offbreak
# 25                JR Hopes 1978-10-24  Right-hand bat        Right-arm medium
#
#            Country_Name
# Player_Id
# 1                 India
# 2           New Zealand
# 3             Australia
# 4             Australia
# 5              Pakistan
# 6                 India
# 7                 India
# 8                 India
# 9          South Africa
# 10            Australia
# 11         South Africa
# 12                India
# 13            Australia
# 14                India
# 15                India
# 16                India
# 17                India
# 18            Australia
# 19            Australia
# 20                India
# 21                India
# 22          New Zealand
# 23                India
# 24                India
# 25            Australia
